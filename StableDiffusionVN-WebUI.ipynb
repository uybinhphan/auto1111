# %% [markdown]
#  # [![](https://img.shields.io/badge/Thiết%20kế-stablediffusion.vn-0075ff)](https://stablediffusion.vn) [![](https://img.shields.io/badge/Group-Support-0075ff)](https://www.facebook.com/groups/stablediffusion.vn) [![](https://img.shields.io/badge/Phiên%20bản-v1.5.08-0075ff)](https://stablediffusion.vn/update/) [![](https://img.shields.io/discord/813085864355037235?color=blue&label=Discord&logo=Discord)](https://discord.gg/5SEtApPeyG) [![](https://img.shields.io/badge/Donate-SDVN-green)](https://stablediffusion.vn/donate/)
#
# [![](https://img.shields.io/badge/Hướng%20dẫn%20-Chi%20tiết-5858e6)](https://stablediffusion.vn/huong-dan-chung/) [![](https://img.shields.io/badge/Video%20hướng%20dẫn-Youtube-E62117)](https://youtu.be/jcJTsmBmyJ0) [![](https://img.shields.io/badge/Bộ%20công%20cụ-Đầy%20đủ-0075ff)](https://stablediffusion.vn/bo-cong-cu/) [![](https://img.shields.io/badge/Tools-Downloads-green)](https://colab.research.google.com/drive/1bbprkrT2gBb_JS8Noi3yxIEEFlV_PWw9#scrollTo=gAg03nKay-G8) [![](https://img.shields.io/badge/Check-Gradio%20Sever-orange)](https://status.gradio.app)

# %% [markdown]
# ---
# ## 💡 Hướng dẫn sử dụng :
# + B1 : Tuỳ chọn phiên bản sử dụng,tuỳ chọn thêm model nếu chưa có sẵn model trên drive ( Các model này chỉ lưu vào bộ nhớ tạm, không chiếm dụng drive ). Trường hợp không có model, SDver1.5 sẽ được tự động tải về colab.
# + B2 :  **Ctr+F9** (Hoặc vào thời gian chạy => Chạy tất cả)
# + B3 : Đồng ý " Vẫn chạy " khi được cảnh báo
# + B4 : Đồng ý kết nối với drive khi được hỏi
# + B5 : Đợi 5 - 7 phút cho tới khi chương trình chạy tới lúc xuất hiện 3 đường link ở kết quả của phần 2
# + B6 : Sử dụng 1 link đuôi gradio để truy cập WebUI và sử dụng
# ---
# ## 💡 Hướng dẫn cài đặt là lấy API với Photoshop Extension :
#
# + Tương thích với bản PTS 2023 mới nhất
# + Cài đặt Extension : [GitHub](https://github.com/AbdullahAlfaraj/Auto-Photoshop-StableDiffusion-Plugin/releases/tag/v1.2.2) , vào link trên, tải file .zip or ccx , giải nén vào thư mục /Photoshop/Plugins và khởi động PTS
# + Chạy chương trình tới khi nhận link giao diện UI ( Hiện tại phiên bản ver2-16 tương thích hoàn toàn, phiên bản ver2-23, ver2update thì có thể xuất hiện lỗi )
# + Copy 1 trong các đường link sử dụng UI ( Ưu tiên nhất cloudflare ) vào Extension ( phần setting ) trên PTS để sử dụng.
#
# ---
# ## 💡 Lưu dữ liệu và tải về :
# - Lưu model tuỳ chọn trên drive tại thư mục : /MyDrive/SD-Data/Model
# - Lưu lora tuỳ chọn trên drive tại thư mục : /MyDrive/SD-Data/Lora
# - Lưu textual tuỳ chọn trên drive tại thư mục : /MyDrive/SD-Data/Embeddings
# - Lưu wildcards cho Dynamic Prompt : /MyDrive/SD-Data/wildcards
# - Lưu Hypernetworks trên drive tại thư mục : /MyDrive/SD-Data/Hypernetworks
# - Tools hỗ trợ download model về drive : [Download tools](https://colab.research.google.com/drive/1bbprkrT2gBb_JS8Noi3yxIEEFlV_PWw9#scrollTo=gAg03nKay-G8)
# ---
# ## 💡 Lưu ý :
#
# 🚩 Nếu không tự động nhận thư mục trong drive, hãy check kỹ lại đường dẫn và tài khoản
#
# 🚩 Nếu không kết nối được GPU ( Hết thời gian dùng GPU miễn phí trong ngày / Hôm sau mới hồi lại được ), hãy đổi tài khoản google khác để sử dụng hoặc nâng cấp pro
#
# 🚩 Chia sẻ thư mục SD-Data và tạo đường dẫn đến drive của tôi đối với tài khoản khác nếu muốn dùng chung dữ liệu và cài đặt ( Lưu ý tk phụ nếu đã có thư mục SD-Data hãy xoá đi, chỉ để đường dẫn lối tắt của tk chính thôi )

# %% [markdown]
# # 🚀 StableDiffusion.VN

# %%
#@title # ⚙️ 1.Tuỳ chọn phiên bản
#Cài môi trường
#@markdown <br> [![](https://img.shields.io/badge/Tra%20cứu%20thông%20tin-Version-blue)](https://stablediffusion.vn/webui-catalog/)
hf_token = "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"
user_header = f'"Authorization: Bearer {hf_token}"'

from google.colab import drive
drive.mount('/content/drive')

# %cd /content
# %env TF_CPP_MIN_LOG_LEVEL=1
# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb
# !pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
# !pip install -q xformers==0.0.19 triton==2.0.0 -U
# !sudo apt-get install aria2

# !rm -r /content/SDVN
Version = "v2-28"  #@param ["v2-16","v2-23","v2-28","v2-update"]
Extensions = "base"  #@param ["base","plus","extraplus","video"]
Controlnet = "base"  #@param ["base","extra"]
Setting = "none" #@param ["none", "update" , "resetall"]

if Version=="v2-16" :
 # !git clone -b v2-16 https://github.com/phamhungd/SDVN-Legacy /content/SDVN
if Version=="v2-23" :
    # !git clone -b v2-23 https://github.com/phamhungd/SDVN
if Version=="v2-28" :
  # !git clone -b v2-28 https://github.com/phamhungd/SDVN
if Version=="v2-update" :
    # !git clone https://github.com/phamhungd/SDVN

# !git clone -b sdvn https://github.com/phamhungd/sd-webui-tunnels/ /content/SDVN/extensions/Tunnels
# !git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/SDVN/extensions/Additional-networks 
# !git clone https://github.com/Mikubill/sd-webui-controlnet /content/SDVN/extensions/sd-webui-controlnet
# !git clone https://github.com/fkunn1326/openpose-editor /content/SDVN/extensions/Openpose-editor
# !git clone https://github.com/hako-mikan/sd-webui-lora-block-weight /content/SDVN/extensions/Block-weight
# !git clone https://github.com/alemelis/sd-webui-ar /content/SDVN/extensions/AR
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-locon /content/SDVN/extensions/A1111-Locon
# !git clone https://github.com/hako-mikan/sd-webui-supermerger /content/SDVN/extensions/Supermerger
# !git clone https://github.com/adieyal/sd-dynamic-prompts /content/SDVN/extensions/Dynamic-prompts
# !git clone https://github.com/phamhungd/Two-shot /content/SDVN/extensions/Two-shot
# !git clone https://github.com/zanllp/sd-webui-infinite-image-browsing /content/SDVN/extensions/Image-browsing
# !git clone https://github.com/richrobber2/canvas-zoom /content/SDVN/extensions/Canvas-zoom 

if Version=="v2-16" :
  # !git clone -b oldver https://github.com/phamhungd/sd-webui-llul /content/SDVN/extensions/B-Llul
  # !git clone https://github.com/AbdullahAlfaraj/Auto-Photoshop-StableDiffusion-Plugin.git /content/SDVN/extensions/Auto-Photoshop

if Version!="v2-16" :
  # !git clone https://github.com/phamhungd/sd-webui-llul /content/SDVN/extensions/B-Llul

if Extensions=="plus" :
  # !git clone https://github.com/hnmr293/sd-webui-cutoff.git /content/SDVN/extensions/Cutoff
  # !git clone https://github.com/ljleb/prompt-fusion-extension /content/SDVN/extensions/Prompt-fusion
  # !git clone https://github.com/phamhungd/Composable-lora /content/SDVN/extensions/Composable-lora
  # !git clone https://github.com/phamhungd/Civitai-Helper /content/SDVN/extensions/Civitai-Helper
  # !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete /content/SDVN/extensions/Tagcomplete
  # !git clone https://github.com/jexom/sd-webui-depth-lib /content/SDVN/extensions/Depth-lib

if Extensions=="extraplus" :
  # !git clone https://github.com/hnmr293/sd-webui-cutoff.git /content/SDVN/extensions/Cutoff
  # !git clone https://github.com/ljleb/prompt-fusion-extension /content/SDVN/extensions/Prompt-fusion
  # !git clone https://github.com/phamhungd/Composable-lora /content/SDVN/extensions/Composable-lora
  # !git clone https://github.com/phamhungd/Civitai-Helper /content/SDVN/extensions/Civitai-Helper
  # !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete /content/SDVN/extensions/Tagcomplete
  # !git clone https://github.com/jexom/sd-webui-depth-lib /content/SDVN/extensions/Depth-lib
  # !git clone https://github.com/eideehi/sd-webui-better-prompt /content/SDVN/extensions/Better-prompt
  # !git clone https://github.com/Coyote-A/ultimate-upscale-for-automatic1111 /content/SDVN/extensions/Ultimate-upscale
  # !git clone https://github.com/ototadana/sd-face-editor /content/SDVN/extensions/Face-editor
  # !git clone https://github.com/pkuliyi2015/multidiffusion-upscaler-for-automatic1111 /content/SDVN/extensions/Tiled-Diffusion
  # !git clone https://github.com/nonnonstop/sd-webui-3d-open-pose-editor /content/SDVN/extensions/3D-Pose
  # !git clone https://github.com/ddPn08/kohya-sd-scripts-webui /content/SDVN/extensions/kohya-sd-scripts-webui

if Extensions=="video" :
  # !git clone https://github.com/Winfredy/SadTalker /content/SDVN/extensions/SadTalker
  # !git clone https://huggingface.co/phamhungd/Sadtalker /content/SDVN/extensions/SadTalker/checkpoints
  # !git clone https://github.com/v8hid/infinite-zoom-automatic1111-webui /content/SDVN/extensions/Infinite-zoom
  # !git clone https://github.com/Scholar01/sd-webui-mov2mov /content/SDVN/extensions/Mov2mov
  # !git clone https://github.com/CiaraStrawberry/TemporalKit /content/SDVN/extensions/TemporalKit
  # !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/SDVN/extensions/deforum-for-automatic1111-webui
  # !git clone https://github.com/s9roll7/ebsynth_utility /content/SDVN/extensions/ebsynth_utility
  # !git clone https://github.com/volotat/SD-CN-Animation /content/SDVN/extensions/SD-CN-Animation

# %cd /content/SDVN

#Controlnet

# !git clone https://huggingface.co/phamhungd/Basecontrolnet /content/Basecontrolnet
# !ln -s /content/Basecontrolnet /content/SDVN/extensions/sd-webui-controlnet/models/Basecontrolnet
if Controlnet == "extra" :
  # !git clone https://huggingface.co/phamhungd/Extracontrolnet /content/Extracontrolnet
  # !ln -s /content/Extracontrolnet /content/SDVN/extensions/sd-webui-controlnet/models/Extracontrolnet

# Library

# !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d /content/SDVN/models/Stable-diffusion -o VAE84.vae.pt
# !aria2c --continue --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/GuoZovya/resolve/main/4x-UltraSharp.ckpt -d /content/SDVN/models/ESRGAN -o 4x-UltraSharp.pth

# !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://stablediffusion.vn/wp-content/uploads/Colab/script/run_n_times.txt -d /content/SDVN/scripts -o run_n_times.py
# !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://stablediffusion.vn/wp-content/uploads/Colab/script/loopback_wave.txt -d /content/SDVN/scripts -o loopback_wave.py
# !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://stablediffusion.vn/wp-content/uploads/Colab/script/multi_frame_render.txt -d /content/SDVN/scripts -o multi_frame_render.py

# !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/params.txt -d /content/SDVN/ -o params.txt
# !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/ui-config.json -d /content/SDVN/ -o ui-config.json

if Version=="v2-update" or Version=="v2-28":
  # !rm /content/SDVN/html/card-no-preview.png
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/card-no-preview.png -d /content/SDVN/html
  # !rm /content/SDVN/style.css
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/style.css -d /content/SDVN/
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/localization.json -d /content/SDVN/localizations
  # !rm /content/SDVN/html/footer.html
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/footer.txt -d /content/SDVN/html -o footer.html
  
#@markdown <br> [![](https://img.shields.io/badge/Tra%20cứu%20thông%20tin-Model-blue)](https://stablediffusion.vn/webui-catalog/)

#Model

#@markdown ## ⚡️ Custom Model
CheckpointDownloadLink = "" #@param {type:"string"}
if CheckpointDownloadLink != "" :
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M {CheckpointDownloadLink} -d /content/SDVN/models/Stable-diffusion

baseUrl = ["",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -d /content/SDVN/models/Stable-diffusion -o StableDiffusion-v14.ckpt",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned.safetensors -d /content/SDVN/models/Stable-diffusion -o StableDiffusion-v15.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-nonema-pruned.safetensors -d /content/SDVN/models/Stable-diffusion -o StableDiffusion-v21-512.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-nonema-pruned.safetensors -d /content/SDVN/models/Stable-diffusion -o StableDiffusion-v21-768.safetensors"]
baseList = ["",
             "StableDiffusion-v14",
             "StableDiffusion-v15",
             "StableDiffusion-v21-512",
             "StableDiffusion-v21-768"]
#@markdown ## 🎇 Base Model
basemodelName = ""  #@param ["", "StableDiffusion-v14","StableDiffusion-v15", "StableDiffusion-v21-512",  "StableDiffusion-v21-768"]
# !{baseUrl[baseList.index(basemodelName)]}
sdvnmodelUrl = ["",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/StableDiffusionVN/resolve/main/SDVN-Real-v1.ckpt -d /content/SDVN/models/Stable-diffusion -o SDVN-Real-v1.ckpt",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/GuoZovya/resolve/main/ChizLucky.ckpt -d /content/SDVN/models/Stable-diffusion -o SDVN-ChizLucky.ckpt",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/GuoZovya/resolve/main/GuoZovyav1.ckpt -d /content/SDVN/models/Stable-diffusion -o SDVN-GuoZovya.ckpt"]
sdvnmodelList = ["",
                 "SDVN-Real-v1",
                 "SDVN-ChizLucky",
                 "SDVN-GuoZovya"]
#@markdown ## 🎇 SDVN Model
sdvnmodel = ""  #@param ["", "SDVN-Real-v1","SDVN-ChizLucky", "SDVN-GuoZovya"]
# !{sdvnmodelUrl[sdvnmodelList.index(sdvnmodel)]}
modelUrl = ["",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11745 -d /content/SDVN/models/Stable-diffusion -o Chilloutmix.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/29460 -d /content/SDVN/models/Stable-diffusion -o RealisticVision.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15236 -d /content/SDVN/models/Stable-diffusion -o Deliberate.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7133 -d /content/SDVN/models/Stable-diffusion -o RPGv4.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/54044 -d /content/SDVN/models/Stable-diffusion -o HenmixRealv23.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/39880 -d /content/SDVN/models/Stable-diffusion -o FantasticRealv3.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/24196 -d /content/SDVN/models/Stable-diffusion -o V08.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/55911 -d /content/SDVN/models/Stable-diffusion -o MajicmixReal.safetensors"]
modelList = ["",
             "Chilloutmix",
             "RealisticVision",
             "Deliberate",
             "RPGv4",
             "HenmixRealv23",
             "FantasticRealv3",
             "V08",
             "MajicmixReal"]
#@markdown ## 🏞️ Realistic model 1
modelName = ""  #@param ["", "Chilloutmix", "RealisticVision", "Deliberate", "RPGv4", "HenmixRealv23", "FantasticRealv3", "V08", "MajicmixReal"]
# !{modelUrl[modelList.index(modelName)]}
#@markdown ## 🏞️ Realistic model 2
model2Name = "" #@param ["", "Chilloutmix", "RealisticVision", "Deliberate", "RPGv4", "HenmixRealv23", "FantasticRealv3", "V08", "MajicmixReal"]
# !{modelUrl[modelList.index(model2Name)]}


model2Url = ["",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7425 -d /content/SDVN/models/Stable-diffusion -o Counterfeit.safetensors",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/OtakupastelwaveMixPro/resolve/main/OtakuMix.safetensors -d /content/SDVN/models/Stable-diffusion -o OtakupastelwaveMixPro.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned-fp16.safetensors -d /content/SDVN/models/Stable-diffusion -o AnythingV4.safetensors",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/StableDiffusionVN/resolve/main/Dalcefov4.safetensors -d /content/SDVN/models/Stable-diffusion -o Dalcefov4.safetensors",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/StableDiffusionVN/resolve/main/Camelliamix.safetensors -d /content/SDVN/models/Stable-diffusion -o Camelliamix.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/27424 -d /content/SDVN/models/Stable-diffusion -o FishMix.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/19348 -d /content/SDVN/models/Stable-diffusion -o OrientalMix.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/36473 -d /content/SDVN/models/Stable-diffusion -o ThreeDelicacyv2.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/DucHaiten/DucHaiten-GODofSIMP/resolve/main/DucHaiten-GODofSIMP_v0.2.safetensors -d /content/SDVN/models/Stable-diffusion -o GODofSIMP.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/17028 -d /content/SDVN/models/Stable-diffusion -o 咸鱼大涂抹.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/40101 -d /content/SDVN/models/Stable-diffusion -o 啥玩意完.safetensors",
            "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14835 -d /content/SDVN/models/Stable-diffusion -o NightSkyYOZORA.safetensors"]
model2List = ["",
             "Counterfeit",
             "OtakupastelwaveMix",
             "AnythingV4",
             "Dalcefov4",
             "Camelliamix",
             "OrientalMix",
             "FishMix",
             "ThreeDelicacyv2",
             "GODofSIMP",
             "咸鱼大涂抹",
             "啥玩意完",
             "NightSkyYOZORA"]
#@markdown ## 🌇 Anime/Paint model 3
model3Name = ""  #@param ["", "Counterfeit", "OtakupastelwaveMix", "AnythingV4", "Dalcefov4", "Camelliamix", "OrientalMix", "FishMix", "ThreeDelicacyv2", "GODofSIMP", "咸鱼大涂抹", "啥玩意完", "NightSkyYOZORA"]
# !{model2Url[model2List.index(model3Name)]}
#@markdown ## 🌇 Anime/Paint model 4
model4Name = ""  #@param ["", "Counterfeit", "OtakupastelwaveMix", "AnythingV4", "Dalcefov4", "Camelliamix", "OrientalMix", "FishMix", "ThreeDelicacyv2", "GODofSIMP", "咸鱼大涂抹", "啥玩意完", "NightSkyYOZORA"]
# !{model2Url[model2List.index(model4Name)]}

#Custom

# !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/sd-vae-ft-ema-original/resolve/main/vae-ft-ema-560000-ema-pruned.safetensors -d /content/SDVN/models/Stable-diffusion -o VAE56.vae.pt
# !aria2c --continue --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/GuoZovya/resolve/main/Waifu-anime.vae.pt -d /content/SDVN/models/Stable-diffusion -o Waifu-anime.vae.pt
# !aria2c --continue --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/GuoZovya/resolve/main/Anime.ckpt -d /content/SDVN/models/Stable-diffusion -o Anime.vae.pt

sample= !ls /content/drive/MyDrive/SD-Data/Setting15
if sample == ["ls: cannot access '/content/drive/MyDrive/SD-Data/Setting15': No such file or directory"] :
  print("Khởi tạo thư mục lần đầu")
  # !mkdir /content/drive/MyDrive/SD-Data/
  # !mkdir /content/drive/MyDrive/SD-Data/Model
  # !mkdir /content/drive/MyDrive/SD-Data/Lora
  # !mkdir /content/drive/MyDrive/SD-Data/Embeddings
  # !mkdir /content/drive/MyDrive/SD-Data/wildcards
  # !mkdir /content/drive/MyDrive/SD-Data/Hypernetworks
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/config.json -d /content/drive/MyDrive/SD-Data/Setting15 -o config.json
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/styles.csv -d /content/drive/MyDrive/SD-Data/Setting15 -o styles.csv

if Setting == "update" :
  print("Update tệp style")
  # !rm /content/drive/MyDrive/SD-Data/Setting15/style.csv
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/styles.csv -d /content/drive/MyDrive/SD-Data/Setting15 -o styles.csv
  
if Setting == "resetall" :
  print("Reset all setting file")
  # !rm -r /content/drive/MyDrive/SD-Data/Setting15
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/config.json -d /content/drive/MyDrive/SD-Data/Setting15 -o config.json
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M http://stablediffusion.vn/wp-content/uploads/Colab/v15/styles.csv -d /content/drive/MyDrive/SD-Data/Setting15 -o styles.csv

# !git clone https://huggingface.co/phamhungd/clone /content/clone
# !git clone https://github.com/phamhungd/WC-SDVN /content/WC-SDVN

# !ln -s /content/drive/MyDrive/SD-Data/Lora /content/SDVN/extensions/Additional-networks/models/lora
# !ln -s /content/drive/MyDrive/SD-Data/wildcards /content/SDVN/extensions/Dynamic-prompts/

# !rm /content/drive/MyDrive/SD-Data/Embeddings/Negative
# !ln -s /content/clone/Negative /content/drive/MyDrive/SD-Data/Embeddings

# !rm /content/drive/MyDrive/SD-Data/Lora/Lora
# !ln -s /content/clone/Lora /content/drive/MyDrive/SD-Data/Lora

# !rm /content/drive/MyDrive/SD-Data/wildcards/WC-SDVN
# !ln -s /content/WC-SDVN /content/drive/MyDrive/SD-Data/wildcards

# !ln -s /content/clone/Model /content/SDVN/models/Stable-diffusion

# %%
#@title # ⌛️ 2.RUN
# !python launch.py --api --share --listen --theme dark --xformers --enable-insecure-extension-access --disable-safe-unpickle --multiple\
 --ui-settings-file /content/drive/MyDrive/SD-Data/Setting15/config.json \
 --styles-file /content/drive/MyDrive/SD-Data/Setting15/styles.csv \
 --ckpt-dir /content/drive/MyDrive/SD-Data/Model \
 --lora-dir /content/drive/MyDrive/SD-Data/Lora \
 --embeddings-dir /content/drive/MyDrive/SD-Data/Embeddings \
 --hypernetwork-dir /content/drive/MyDrive/SD-Data/Hypernetworks
